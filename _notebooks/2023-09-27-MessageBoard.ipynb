# %% [markdown]
# ---
# comments: true
# layout: post
# title: Message Board
# description: Messaging
# type: hacks
# courses: {compsci: {week: 5}}
# ---

# %% [markdown]
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Message Board</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#     }
#
#     #message-input {
#       width: 80%;
#       padding: 10px;
#     }
#
#     #message-container {
#       margin-top: 20px;
#     }
#
#     .error {
#       color: red;
#     }
#   </style>
# </head>
#
# <body>
#   <h1>Message Board</h1>
#   <form id="message-form">
#     <textarea id="message-input" placeholder="Enter your message"></textarea> <!-- Text entry -->
#     <button type="button" onclick="addMessage()">Add Message</button><!-- Button Submission -->
#   </form>
#   <button onclick="updatePage()">Update Page</button> <!-- Updates page -->
#   <p id="error-message" class="error"></p>
#   <div id="message-container"> <!-- Preserves text -->
#     <h2>Messages:</h2>
#     <ul id="messages"></ul>
#   </div>
#
#   <script>
#     function addMessage() {
#       const messageInput = document.getElementById('message-input');
#       const message = messageInput.value;
#       const errorMessage = document.getElementById('error-message');
#
#       if (message.trim()) {
#         errorMessage.textContent = '';
#         const messagesList = document.getElementById('messages');
#         const messageItem = document.createElement('li');
#         messageItem.textContent = message;
#         messagesList.appendChild(messageItem);
#         messageInput.value = '';
#       }
#       else {
#         errorMessage.textContent = 'Message cannot be empty!';
#       }
#     }
#
#     function updatePage() {
#       location.reload(); // This will reload the page
#     }
#   </script>
# </body>
#
# </html>

# %% [markdown]
# %%html
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Button Example</title>
# </head>
#
# <body>
#
#     <button onclick="myFunction()">Click Me</button>
#
#     <p id="demo">Dont click me </p>
#
#     <script>
#         function myFunction() {
#             document.getElementById("demo").innerHTML = "Are u serious right neow?";
#         }
#     </script>
#
# </body>
#
# </html>

# %% [markdown]
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Message Board</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       margin: 0;
#       padding: 0;
#       display: flex;
#       flex-direction: column;
#       align-items: center;
#     }
#
#     #post-form {
#       margin: 20px;
#     }
#
#     #post-input {
#       padding: 10px;
#       width: 80%;
#     }
#
#     #posts {
#       margin-top: 10px;
#       width: 80%;
#     }
#
#     .post {
#       border: 1px solid #ccc;
#       padding: 10px;
#       margin-bottom: 10px;
#       border-radius: 5px;
#     }
#   </style>
# </head>
#
# <body>
#   <h1>Message Board</h1>
#   <div id="post-form">
#     <input type="text" id="post-input" placeholder="Type your message here">
#     <button onclick="addPost()">Add Post</button>
#   </div>
#
#   <div id="posts">
#     <!-- Current posts will be appended here -->
#   </div>
#
#   <script>
#     function addPost() {
#       const postInput = document.getElementById('post-input');
#       const postsDiv = document.getElementById('posts');
#
#       // Creating a new div for the post
#       const newPost = document.createElement('div');
#       newPost.className = 'post';
#       newPost.textContent = postInput.value;
#
#       // Appending the new post to the posts div
#       postsDiv.appendChild(newPost);
#
#       // Clearing the input field
#       postInput.value = '';
#     }
#
#     // Optionally, you can fetch and display current posts from your server here
#   </script>
# </body>
#
# </html>
